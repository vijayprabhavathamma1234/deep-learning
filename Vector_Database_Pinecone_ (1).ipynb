# %% [markdown]
# <a href="https://colab.research.google.com/github/PradipNichite/Youtube-Tutorials/blob/main/Vector_Database_Pinecone_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Vector databases** are purpose-built to handle the unique structure of **vector embeddings**. They **index vectors** for **easy search and retrieval** by comparing values and finding those that are most similar to one another.

# %%
# !pip install sentence-transformers pinecone-client -q
# https://app.pinecone.io/organizations/-NbESj9IBA3A__T-C_rJ/projects/gcp-starter:94f453d/keys
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 80.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.3/300.3 kB 32.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
# https://www.kaggle.com/datasets/quora/question-pairs-dataset
data = pd.read_csv("/content/questions.csv")
data.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
len(data)
# Out:
# 404351

# %%
data=data.tail(140)
data
# Out:
#             id    qid1    qid2  \
# 404211  404211  789526  789527
# 404212  404212  789528  789529
# 404213  404213  789530  789531
# 404214  404214  789532  789533
# 404215  404215  789534  789535
# ...        ...     ...     ...
# 404346  404346  789792  789793
# 404347  404347  789794  789795
# 404348  404348  789796  789797
# 404349  404349  789798  789799
# 404350  404350  789800  789801
#
#                                                 question1  \
# 404211  What is the difference among Mythology, Theolo...
# 404212  Do I need Xcode to publish a book in apple sto...
# 404213  In the Bible, was the forbidden fruit a metaph...
# 404214       What's the best way to stop procrastinating?
# 404215  I am about to be 25 and have left my job for s...
# ...                                                   ...
# 404346  How many keywords are there in the Racket prog...
# 404347          Do you believe there is life after death?
# ...

# %%
data.head(20)
# Out:
#             id    qid1    qid2  \
# 404211  404211  789526  789527
# 404212  404212  789528  789529
# 404213  404213  789530  789531
# 404214  404214  789532  789533
# 404215  404215  789534  789535
# 404216  404216  789536  789537
# 404217  404217  789538  789539
# 404218  404218  789540  789541
# 404219  404219  789542  789543
# 404220  404220  572987  789544
# 404221  404221  789545  789546
# 404222  404222  789547  789548
# 404223  404223  789549  789550
# 404224  404224  789551  789552
# 404225  404225  789553  789554
# 404226  404226  789555  789556
# 404227  404227  789557  789558
# 404228  404228  789559  789560
# 404229  404229  789561  789562
# 404230  404230  789563  789564
#
#                                                 question1  \
# 404211  What is the difference among Mythology, Theolo...
# 404212  Do I need Xcode to publish a book in apple sto...
# 404213  In the Bible, was the forbidden fruit a metaph...
# ...

# %%
data.shape
# Out:
# (140, 6)

# %%
data[data['is_duplicate']==1].head()
# Out:
#             id    qid1    qid2  \
# 404214  404214  789532  789533
# 404216  404216  789536  789537
# 404218  404218  789540  789541
# 404223  404223  789549  789550
# 404229  404229  789561  789562
#
#                                                 question1  \
# 404214       What's the best way to stop procrastinating?
# 404216  What made Tata group chairman Cyrus Mistry to ...
# 404218                 Is Donald Trump really a Democrat?
# 404223  What are the options for a chemical engineer a...
# 404229      What are some good sites for learning Python?
#
#                                                 question2  is_duplicate
# 404214      What is the best way to kill procrastination?             1
# 404216  Why Cyrus Mistry has been removed from Tata Gr...             1
# 404218  Is it possible that Donald Trump is in cahoots...             1
# 404223  What are the career opportunities after finish...             1
# ...

# %%
import pinecone
pinecone.init(api_key='2f5a40f6-0fa1-483a-b807-4e560cb68c9a', environment='gcp-starter')
# Out:
# /usr/local/lib/python3.10/dist-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-mpnet-base-v2',device='cuda')

# %%
embeding = model.encode("This is sentence")
len(embeding)
# Out:
# 768

# %%
pinecone.create_index(name='question-search', dimension=768)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-13-d2bf7148350b> in <cell line: 1>()
# ----> 1 pinecone.create_index(name='question-search', dimension=768)
#
# /usr/local/lib/python3.10/dist-packages/pinecone/manage.py in create_index(name, dimension, timeout, index_type, metric, replicas, shards, pods, pod_type, index_config, metadata_config, source_collection)
#     116     api_instance = _get_api_instance()
#     117
# --> 118     api_instance.create_index(create_request=CreateRequest(
#     119         name=name,
#     120         dimension=dimension,
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in __call__(self, *args, **kwargs)
#     774
#     775         """
# --> 776         return self.callable(self, *args, **kwargs)
#     777
#     778     def call_with_http_info(self, **kwargs):
#
# ...

# %%
index = pinecone.Index('question-search')

# %%
# [(id,vector,metadata)]

# %%
question_list = []
for i,row in data.iterrows():
  question_list.append(
      (
        str(row['id']),
        model.encode(row['question1']).tolist(),
        {
            'is_duplicate': int(row['is_duplicate']),
            'question1': row['question1']
        }
      )
  )
  if len(question_list)==50 or len(question_list)==len(data):
    index.upsert(vectors=question_list)
    question_list = []
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-15-ee576d1f98ac> in <cell line: 2>()
#      12   )
#      13   if len(question_list)==50 or len(question_list)==len(data):
# ---> 14     index.upsert(vectors=question_list)
#      15     question_list = []
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/utils/error_handling.py in inner_func(*args, **kwargs)
#      15         Config.validate()  # raises exceptions in case of invalid config
#      16         try:
# ---> 17             return func(*args, **kwargs)
#      18         except MaxRetryError as e:
#      19             if isinstance(e.reason, ProtocolError):
#
# /usr/local/lib/python3.10/dist-packages/pinecone/index.py in upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     148
#     149         if batch_size is None:
# ...

# %%
# query = "How do I prepare for civil service?"
query = "How do I prepare for python?"
xq = model.encode([query]).tolist()
result = index.query(xq, top_k=2, includeMetadata=True)
result
# Out:
# {'matches': [{'id': '35535',
#               'metadata': {'is_duplicate': 1.0,
#                            'question1': 'What are some tips for learning '
#                                         'python?'},
#               'score': 0.81990093,
#               'values': []},
#              {'id': '46204',
#               'metadata': {'is_duplicate': 0.0,
#                            'question1': 'How do I get started with Python?'},
#               'score': 0.817917347,
#               'values': []}],
#  'namespace': ''}

# %%
query = "How to levergae internet for business"
xq = model.encode([query]).tolist()
result = index.query(xq, top_k=2, includeMetadata=True)
result
# Out:
# {'matches': [{'id': '25495',
#               'metadata': {'is_duplicate': 0.0,
#                            'question1': 'How can you systematize your Internet '
#                                         'startup business?'},
#               'score': 0.685297549,
#               'values': []},
#              {'id': '7850',
#               'metadata': {'is_duplicate': 1.0,
#                            'question1': 'How to start business on internet?'},
#               'score': 0.663540125,
#               'values': []}],
#  'namespace': ''}
